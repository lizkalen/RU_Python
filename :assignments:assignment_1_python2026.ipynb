# %% [markdown]
# # **Assignment 1**
#
# Last update: 01/09/2026
#
# Created by dr. C. Tejedor-García
#
# Python LET-REMA-LC2601
#
# Radboud University Nijmegen

# %% [markdown]
# ##Due date

# %% [markdown]
# This assignment is due on Tuesday the 14th of September 2026 at 23:00 (11:00PM) CEST.

# %% [markdown]
# ##Instructions

# %% [markdown]
# In [colab.google](colab.google) and using your own account, upload this Colab Notebook file.
#
# Second, change its name with your surname and assignment number (on the top left corner of the screen) to: ***yoursurname_assignment_X_python2026.ipynb***
#
# After reading carefully the Instructions and Asseessment, please write each exercise's code (or use comments to answer in written text) in a separate code block (cell) on your Notebook. In order to run your code, you will need to click on the "play" button of each exercises as follows:
#
# ![image.png](data:image/png;base64,...)
#
# Finally, when you have finished the assignment, click on the "Share" button on the Notebook screen and make it public (it will be only be accesible when teh teacher uses the URL). Then copy&paste the public URL (“Copy link” button) to your Brightspace assignment submission.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Assessment

# %% [markdown]
# Each exercise will be graded as incorrect (0), almost correct (0.5), or correct (1). There is not a single uniquely correct answer. **All your code cells need to have at least one (short) comment explaining your choices and code. Otherwise, they will not be graded.** Please be creative with your responses, but always under the scope of the content seen in the course. The use of AI is not permitted for completing this assignment. The average score of the exercises, scaled from 0 to 10, will be shared on Brightspace along with corrective feedback.

# %% [markdown]
# # Block 1

# %% [markdown]
# ## EX01

# %% [markdown]
# Write a script that prints on the screen your first name in one line and your surname(s) in a second line.

# %%
# Your answer here

# %% [markdown]
# ##EX02

# %% [markdown]
# Indicate for the following items whether they are hardware or software:
# 1.  Webcam
# 1.  Web browser (e.g., Firefox, Opera, Chrome…)
# 1.  Database (e.g., mongodb, oracle…)
# 1.  Memory stick
# 1.  Holiday pictures stored on a memory stick

# %% [markdown]
# Your answer here.

# %% [markdown]
# ##EX03

# %% [markdown]
# A directory in another directory is called a subdirectory. Can you also have a subfile? Explain why or why not

# %% [markdown]
# Your answer here.

# %% [markdown]
# ##EX04

# %% [markdown]
# What is the output of the code below? Please note that this is a code-reading exercise, you are not supposed to write and run teh code, just read and understand it 😊

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##EX05

# %% [markdown]
# Write a script that prints the answer of the division of 69 by 5. Use variables.

# %%
# Your answer here

# %% [markdown]
# ##EX06

# %% [markdown]
# A computer program can be compared to a (cooking) recipe. In your own words, name three important differences between a computer program and a recipe.

# %% [markdown]
# Your answer here.

# %% [markdown]
# ##EX07

# %% [markdown]
# What is a variable useful for (in programming)?

# %% [markdown]
# Your answer here.

# %% [markdown]
# ##EX08

# %% [markdown]
# Velocity is the distance divided by the time that it takes to cover that distance. Suppose we walk 69 kilometers in 15 hours.
# 1.   Then what is the velocity? What is the velocity in meters per minute? Use
# variables for all values that you use in the equations when computing the velocity.
# 2.	Now we walk 85 kilometers at the same speed. How long will that take us in minutes? Use the same code as above and try to use as little code as possible.

# %%
# Your answer a) here

# %%
# Your answer b) here

# %% [markdown]
# ##EX09

# %% [markdown]
# In your own words, without running the code, what is wrong with the code below? If you tried to run the code below, would it give an error? If so, what kind of error?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Your answer here

# %% [markdown]
# ##EX10

# %% [markdown]
# Most programs are made up of combinations of only five basic instruction types (input, output, math, conditional execution, and repetition). Given that this is the case, what do you think is the first step a programmer needs to undertake when they start working out a program for a big and complex task?

# %% [markdown]
# Your answer here

# %% [markdown]
# ##EX11

# %% [markdown]
# The code below contains a number of errors and formatting problems. Which ones? Please specify the line numbers and errors. ![image.png](data:image/png;base64,...)

# %% [markdown]
# Your answer here

# %% [markdown]
# ##EX12

# %% [markdown]
# How could you solve the problems in the code shown in exercise 11, ***without*** changing anything in lines 1-6? That is, only by changing something in lines 8-10?

# %%
# Your answer here

# %% [markdown]
# ##EX13

# %% [markdown]
# Why is it good to use meaningful variable names? What can be the downside of using very long and explicit variable names?

# %% [markdown]
# Your answer here.

# %% [markdown]
# ##EX14

# %% [markdown]
# Look at the code below. Six variable names are used. For each of the first 7 lines in the code, provide the values of the variables that are present in each line. ***Remember, you are not supposed to run the code to see each value.***![image.png](data:image/png;base64,...)

# %% [markdown]
# Your answer here.

# %% [markdown]
# ##EX15

# %% [markdown]
# Suppose there is a pandemic and you have to keep a distance from each other.
# Imagine you want to fill a room with students at an appropriate distance from each other given these pandemic regulations. The room is 25 meters by 25 meters. A table with one student sitting at it is 120 cm by 70 cm. There has to be 1.5 m space between each table+student unit on all sides. There also has to be 1.5 m space between the wall and the students sitting at the edge.
#
#
# 1. How many students can you fit in the room? Use variables for each of your
# calculations.
#
#
# 2.  What if the rule is to have 2 m space. between each table+student unit, as well as between the wall and the students sitting at the edge?
#
#
# Hint:
#
# ![image.png](data:image/png;base64,...)

# %%
# Your answer here

# %% [markdown]
# # Block 2

# %% [markdown]
# ## EX01

# %% [markdown]
# Using your own words:
#
# 1.1. What is the main difference between the data types String and List?
#
# 1.2. What is the main difference between the data types Set and Dictionary?
#
# 1.3. What does that allow you to do with strings and lists that you cannot do with integers and floats?

# %% [markdown]
# Your answer here

# %% [markdown]
# ## EX02

# %% [markdown]
# Look at the code below. What is the output of the print statements per line? Give your answers without running the code in a Python interpreter 😊
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Your answer here

# %% [markdown]
# ## EX03

# %% [markdown]
# Explain with your own words what 'mutability' means when we refer to Lists and Strings and give one example in Python for both data types in which we can see their (im)mutability property.

# %% [markdown]
# Your answer here

# %% [markdown]
# ## EX04

# %% [markdown]
# Create two lists, one containing three strings with a color (of your choice) and one containing three strings with a piece of furniture (of your choice). Now create a new list containing three strings with colored furniture, such that the first piece of furniture should have the last color of your previously defined lists, the second piece of furniture the second color and the last piece of furniture the first color (you do not have to bother about ‘a space/blank’ between the color and the furniture).

# %%
# Your answer here

# %% [markdown]
# ## EX05

# %% [markdown]
# The little piece of code below has three errors. Which ones and how can you correct them?
#
# ![image.png](data:image/png;base64,...)

# %%
# Your answer here

# %% [markdown]
# ## EX06

# %% [markdown]
# Write a piece of code that (1) uses the following variable:
#
# `my_text = "  H3ll0, W0rld, th!s string_h@s $0m€ st€r@ang%e ch@ar@ct3rs & th!ngs  "`
#
# and (2) removes all its special characters from it; i.e. all characters that do not occur in the Latin alphabet. Use only Python methods and functions for Strings. Hint: The printed output must be:
#   `HelloWorldthisstringhsomstrangecharctersthings`

# %%
# Your answer here

# %% [markdown]
# ## EX07

# %% [markdown]
# The text below is very gender biased. The writer regrets the choice for the boy doing things that are traditionally viewed as "masculine" and the girl doing things that are traditionally viewed as "feminine", and wants to swap the names. What is wrong with the way the writer uses the replace statement in the code script below? Give an alternative that works. Try to solve the exercise without running code.
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Your answer here

# %% [markdown]
# ## EX08

# %% [markdown]
# With your own words, provide one example with Python in which you would use sets instead of lists and another one of choosing dictionaries over lists. Second, provide also a simple and short example for each case using Python code.

# %% [markdown]
# Your answer here

# %%
# Your code/answer here

# %% [markdown]
# ## EX09

# %% [markdown]
# Old Dutch had twelve `common_words` in its vocabulary: a*pful, bok, dag, drincan, gans, hand, hus, lam, man, ring, stain, and sunu*. Imagine that we are in the year 2029 and (1) a new borrowing enters the language (*café*), and (2) the word *hus* changes its spelling to *huis* (all other words remain unchanged). Then, in the year 3210, Dutch borrows three more words from other languages: theater, museum, and opera. However, after thirty years, language usage changes again and theater and museum fall completely out of use, disappearing from the language. Tasks:
#
# 1. Using always the same variable `common_words` as a list, write a piece of Python code that reflects every step described above using the Python list methods you consider necessary.
#
# 2. Make sure that you print the value of the variable `common_words` at the end of your code alphabetically ordered and print out the number of `common_words` left in the vocabulary at the end of the year 3240.
#
# Hint: Remember, Python does have several useful functions and methods for lists 😊

# %%
# Your answer here

# %% [markdown]
# ## EX10

# %% [markdown]
# Look at the code below. What is the output of the print statement? Give the answer without copying the code in a Python interpreter 😊
#
# ![image.png](data:image/png;base64,...)

# %%
# Your answer here

# %% [markdown]
# ## EX11

# %% [markdown]
# What are the differences between a list and a set in Python? Is it possible to turn one list variable into a set, and vice versa? If so, provide examples with Python code.

# %% [markdown]
# Your answer here

# %%
# Your code and answer here

# %% [markdown]
# ## EX12

# %% [markdown]
# Define a Python `set` that contains all the characters of the Latin alphabet. Using a `set` method or operator, print out the shared characters between the Latin alphabet `set` and your name (first name and last name). Also show on the screen the alphabetically sorted list that results from eliminating the characters of your name from the initial Latin alphabet `set` (again, using Python `set` methods/functions/operators).
#
# Remember that you cannot use conditional statements or loops to solve this problem yet 😊

# %%
# Your answer here

# %% [markdown]
# ## EX13

# %% [markdown]
# Suppose you have a small lexicon with words (orthographical transcriptions) and their phonetic transcriptions:
#
# ```
# hello   hVl@U
# good    gUd
# morning mO:RnIN
# how     haU
# are     QR
# you     ju:
# doing   du:IN
# ```
#
#
# a)	Represent the lexicon with the Python data type you consider more adequate.
#
# b)	Add a new entry:`beautiful bju:tVfVl`
#
# c)	Print out only the orthographical transcriptions of all words (but not their phonetic transcriptions).
#
# d)	Using your lexicon variable (and probably a couple of lists), now create a single String variable with the following format and print it out (you will notice that the code line you need is super long):
#
# `ortho_first_word+phon_last_word + … + ortho_last_word+phon_first_word`
#
# Hint: again, besides the variables you created in c), now you also need a new list variable with all orthographic transcriptions, so you can combine values of both lists for creating the final string variable.
# The output must be: `hellobju:tVfVlgooddu:INmorningju:howQRarehaUyoumO:RnINdoinggUdbeautifulhVl@U`

# %%
# Your answer here

# %% [markdown]
# ## EX14

# %% [markdown]
# The goal of the code below is to print relevant information about rap music in USA (rappers, albums and songs). What is wrong with the code below? Provide three errors.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Your answer here.

# %% [markdown]
# ## EX15

# %% [markdown]
# *TinyEnglish* and *TinyDutch* are two very simple languages. They both consist of 12 strings with the same meaning:
#
#
# ```
# TinyEnglish TinyDutch
# Say         zeggen
# so          zo
# I           ik
# say         zeg
# like        als
# you         jij
# mean        bedoelen
# what        wat
# you're      je bent
# trying      proberen
# to          te
# do          doen
#
# ```
#
# Now we are going to make a very basic and dummy Machine Translation system that translates from TinyEnglish to TinyDutch. Suppose we have the following string:
#
# `sentence = "Say=so=I=say=so=I=say=so"`
#
# Notice the `=` symbol is included in the string to make this exercise more interesting 😊.
# We can split that string into a list of words with the method split so that every word is an item in the list.
#
# Translate the TinyEnglish sentence to TinyDutch by using a python dictionary and a list that you create with split. The output must be: `zeggen zo ik zeg zo ik zeg zo`
#
# ***Hint***: The translation must be a unique String variable which consists of the concatenation of the translation of each one of the words.

# %%
# Your answer here
